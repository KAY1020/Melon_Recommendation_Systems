# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from datetime import datetime as dt
import requests
import numpy as np
import pandas as pd

# %%
artarr = np.zeros((70, 4), dtype='>U60')

# %%
def crawlArtistFeatures(url):
    res = requests.get(url, headers={"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0 rv:11.0) like Gecko"})
    res.raise_for_status()
    
    driver = webdriver.Chrome()
    driver.get(url)
    for syllable in range(1, 15):
        for i in range(1, 6):
            click = driver.find_element_by_css_selector('#conts > div.wrap_finder.atist > dl > dd > div.wrap_btn_atist.first_child > button:nth-child('+str(syllable)+')')
            click.click()

            driver.maximize_window() 
            driver.implicitly_wait(10)



            artistClick = driver.find_element_by_css_selector('#pageList > div.list_atist12.d_artist_list > ul > li:nth-child('+ str(i) +') > div > div > dl > dt > a')
            artistClick.click()

            driver.implicitly_wait(10)

            detailinfo = driver.find_element_by_css_selector('#conts > div.wrap_tab_atist > ul > li:nth-child(2) > a')
            detailinfo.click()


            soup = BeautifulSoup(driver.page_source, 'html.parser')

            artist = soup.select('#conts > div.wrap_dtl_atist > div > div.wrap_atist_info > p')
            features_dt = soup.select('#conts > div.section_atistinfo03 > dl > dt')
            features = soup.select('#conts > div.section_atistinfo03 > dl > dd')
    #         print(features_dt)
    #         print(features)
    #         print(artist[0].text.strip().replace("아티스트명",""))
            artistproc1 = artist[0].text.strip().replace("아티스트명","")
            artistproc2 = artistproc1.replace(u"\xa0", u" ")
            artarr[((syllable-1)*5) + i-1, 0] = artistproc2

            j = 1
            if features_dt[0].text.strip() == "데뷔":
                if features_dt[2].text.strip() == "결성일":
                    for k in [1, 3, 4]:
                        feature = features[k].text.strip().split('\n')
                        artarr[((syllable-1)*5) + i-1, j] = ''.join(feature).replace("\t", "")
                        j = j + 1
                else:
                    for k in range(1, 4):
                        feature = features[k].text.strip().split('\n')
                        artarr[((syllable-1)*5) + i-1, j] = ''.join(feature).replace("\t", "")
                        j = j + 1
            elif features_dt[0].text.strip() == "활동년대":
                 for k in range(0, 3):
                    feature = features[k].text.strip().split('\n')
                    artarr[((syllable-1)*5) + i-1, j] = ''.join(feature).replace("\t", "")
                    j = j + 1

            driver.back()
            driver.back()

    driver.quit()

crawlArtistFeatures('https://www.melon.com/artistplus/finder/index.htm')

# %%
artarr
# Out:
# array([['기리보이 (홍시영)', '2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 인디음악'],
#        ['김필', '2010 년대', '솔로|남성',
#         '발라드, 댄스, R&B/Soul, 인디음악, 록/메탈, 포크/블루스'],
#        ['김동률', '1990, 2000, 2010 년대', '솔로|남성', '발라드'],
#        ['김하온 (HAON)', '2010 년대', '솔로|남성', '발라드, 랩/힙합'],
#        ['김소유 (김소희)', '2010 년대', '솔로|여성', '성인가요'],
#        ['닐로(Nilo)', '2010 년대', '솔로|남성', '발라드'],
#        ['나얼 (유나얼)', '1990, 2000, 2010 년대', '솔로|남성',
#         '발라드, R&B/Soul, CCM, 국내CCM'],
#        ['나플라(nafla)', '2010 년대', '솔로|남성', '랩/힙합, 인디음악'],
#        ['뉴이스트', '2010 년대', '그룹|남성', '발라드, 댄스'],
#        ['넬 (NELL)', '2000, 2010 년대', '그룹|남성',
#         '발라드, 댄스, POP, 록/메탈, 일렉트로니카'],
#        ['다비치', '2000, 2010 년대', '그룹|여성', '발라드, 댄스, 랩/힙합, R&B/Soul'],
#        ['다이나믹 듀오', '2000, 2010 년대', '그룹|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 록/메탈, CCM, 국내CCM'],
#        ['더보이즈(THE BOYZ)', '2010 년대', '그룹|남성',
#         '발라드, 댄스, R&B/Soul, 일렉트로니카'],
#        ['디오 (D.O.)', '2010 년대', '솔로|남성', '발라드, R&B/Soul'],
#        ['드림캐쳐', '2010 년대', '그룹|여성', '발라드, 댄스, POP, 록/메탈, J-POP'],
#        ['릴러말즈 (Leellamarz)', '2010 년대', '솔로|남성', '랩/힙합, R&B/Soul'],
#        ['롤러 코스터', '1990, 2000 년대', '그룹|혼성',
#         '발라드, 댄스, 인디음악, 록/메탈, 일렉트로니카'],
#        ['러블리즈', '2010 년대', '그룹|여성', '발라드, 댄스'],
#        ['로꼬 (권혁우)', '2010 년대', '솔로|남성', '발라드, 댄스, 랩/힙합, R&B/Soul, 포크'],
#        ['린 (이세진)', '2000, 2010 년대', '솔로|여성', '발라드, 댄스, R&B/Soul, 록/메탈'],
#        ['매드클라운', '2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 인디음악, 록/메탈'],
#        ['마마무(Mamamoo)', '2010 년대', '그룹|여성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 록/메탈'],
#        ['멜로망스', '2010 년대', '그룹|남성', '발라드, 댄스, 인디음악, 록/메탈, 포크/블루스'],
#        ['몬스타엑스', '2010 년대', '그룹|남성', '발라드, 댄스, 랩/힙합, R&B/Soul'],
#        ['마인드유', '2010 년대', '그룹|남성', '발라드, R&B/Soul, 인디음악, 포크/블루스'],
#        ['방탄소년단', '2010 년대', '그룹|남성', '발라드, 댄스, 랩/힙합, R&B/Soul, 록/메탈'],
#        ['브라운 아이드 소울', '2000, 2010 년대', '그룹|남성', '발라드, R&B/Soul'],
#        ['볼빨간사춘기', '2010 년대', '그룹|여성', '발라드, 댄스, 인디음악, 록/메탈, 포크'],
#        ['박재범 (Jay Park)', '2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 일렉트로니카'],
#        ['배치기', '2000, 2010 년대', '그룹|남성', '발라드, 댄스, 랩/힙합'],
#        ['송가인', '2010 년대', '솔로|여성', '발라드, 댄스, 성인가요'],
#        ['사이먼 도미닉 (정기석)', '2000, 2010 년대', '솔로|남성', '발라드, 댄스, 랩/힙합'],
#        ['선미 (이선미)', '2000, 2010 년대', '솔로|여성', '발라드, 댄스'],
#        ['세븐틴', '2010 년대', '그룹|남성', '발라드, 댄스, 랩/힙합, R&B/Soul'],
#        ['소녀시대 (GIRLS` GENERATION)', '2000, 2010 년대', '그룹|여성',
#         '발라드, 댄스, POP, 록/메탈, 일렉트로니카, R&B/Soul, 블루스, J-POP, 키즈, 만화'],
#        ['아이유', '2000, 2010 년대', '솔로|여성',
#         '발라드, 댄스, 랩/힙합, 록/메탈, 일렉트로니카, R&B/Soul, 포크'],
#        ['염따 (염현수)', '2010 년대', '솔로|남성', '랩/힙합, 인디음악'],
#        ['영비 (양홍원)', '2010 년대', '솔로|남성', '인디음악, 랩/힙합'],
#        ['악동뮤지션', '2010 년대', '그룹|혼성',
#         '발라드, 댄스, 랩/힙합, 록/메탈, 포크/블루스, 일렉트로니카'],
#        ['임창정', '1990, 2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 일렉트로니카, POP, 록/메탈'],
#        ['적재 (정재원)', '2010 년대', '솔로|남성', '발라드, 댄스, 인디음악, 록/메탈, 재즈, 뉴에이지'],
#        ['장범준', '2010 년대', '솔로|남성', '발라드, 댄스, 록/메탈, 포크/블루스'],
#        ['조승연', '2010 년대', '솔로|남성', 'R&B/Soul'],
#        ['장원영', '2010 년대', '솔로|여성', 'IZ*ONE (아이즈원)'],
#        ['지코 (ZICO)', '2010 년대', '솔로|남성', '발라드, 댄스, 록/메탈, 랩/힙합, R&B/Soul'],
#        ['창모 (CHANGMO)', '2010 년대', '솔로|남성', '댄스, 랩/힙합, 인디음악'],
#        ['청하', '2010 년대', '솔로|여성', '발라드, 댄스, R&B/Soul, 록/메탈, 포크/블루스'],
#        ['차준호', '2010 년대', '솔로|남성', 'X1 (엑스원)'],
#        ['첸 (CHEN) (김종대)', '2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, 포크/블루스, 일렉트로니카'],
#        ['최서현', '2010 년대', '솔로|남성', '록/메탈, 랩/힙합'],
#        ['키 (KEY)', '2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, R&B/Soul, 록/메탈, 일렉트로니카'],
#        ['케이시 (Kassy)', '2010 년대', '솔로|여성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 록/메탈'],
#        ['케이윌 (김형수)', '2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 록/메탈'],
#        ['클래지콰이', '2000, 2010 년대', '그룹|혼성',
#         '발라드, 댄스, POP, 록/메탈, 일렉트로니카, R&B/Soul, J-POP'],
#        ['카더가든', '2010 년대', '솔로|남성', '발라드, R&B/Soul, 록/메탈, 포크/블루스'],
#        ['태연 (TAEYEON)', '2000, 2010 년대', '솔로|여성',
#         '발라드, 댄스, R&B/Soul, 록/메탈'],
#        ['태민 (TAEMIN) (이태민)', '2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, R&B/Soul'],
#        ['티아라', '2000, 2010 년대', '그룹|여성', '발라드, 댄스, 일렉트로니카'],
#        ['토이', '1990, 2000, 2010 년대', '솔로|남성', '발라드, 댄스, POP'],
#        ['태양 (동영배)', '2000, 2010 년대', '솔로|남성',
#         '발라드, 댄스, 일렉트로니카, POP, 랩/힙합, R&B/Soul, J-POP'],
#        ['폴킴', '2010 년대', '솔로|남성', '발라드, 랩/힙합, R&B/Soul'],
#        ['펀치 (Punch)', '2010 년대', '솔로|여성', '발라드, 랩/힙합, R&B/Soul'],
#        ['핑클 (Fin.K.L)', '1990, 2000, 2010 년대', '그룹|여성', '발라드, 댄스'],
#        ['프로미스나인', '2010 년대', '그룹|여성', '댄스'],
#        ['포맨', '1990, 2000, 2010 년대', '그룹|남성',
#         '발라드, 댄스, POP, 록/메탈, R&B/Soul'],
#        ['휘인 (Whee In)', '2010 년대', '솔로|여성', '발라드, 댄스, R&B/Soul, 록/메탈'],
#        ['홍자 (박지민)', '2010 년대', '솔로|여성', '발라드, 댄스, 성인가요'],
#        ['헤이즈 (Heize)', '2010 년대', '솔로|여성',
#         '발라드, 댄스, 랩/힙합, R&B/Soul, 인디음악'],
#        ['한요한', '2010 년대', '솔로|남성', '발라드, 랩/힙합, R&B/Soul'],
#        ['황윤성', '2010 년대', '솔로|남성', '댄스']], dtype='>U60')

# %%
df = pd.DataFrame(artarr, columns=['artists', 'year', 'type', 'genre'])

# %%
df.set_index('artists', inplace=True)

# %%
df['year'] = df['year'].str.replace(' 년대', '')
df['type'] = df['type'].str.replace('|', ', ')
df['type'] = df['type'].str.replace('솔로', 'Solo')
df['type'] = df['type'].str.replace('그룹', 'Group')
df['type'] = df['type'].str.replace('남성', 'Male')
df['type'] = df['type'].str.replace('여성', 'Female')
df['type'] = df['type'].str.replace('혼성', 'Both')
df['genre'] = df['genre'].str.replace('발라드', 'Ballad')
df['genre'] = df['genre'].str.replace('댄스', 'Dance')
df['genre'] = df['genre'].str.replace('랩/힙합', 'Rap/Hiphop')
df['genre'] = df['genre'].str.replace('인디음악', 'Indie')
df['genre'] = df['genre'].str.replace('록/메탈', 'Rock/Metal')
df['genre'] = df['genre'].str.replace('포크/블루스', 'Folk/Blues')
df['genre'] = df['genre'].str.replace('국내CCM', 'Korean CCM')
df['genre'] = df['genre'].str.replace('뉴에이지', 'Newage')
df['genre'] = df['genre'].str.replace('일렉트로니카', 'Electronica')
df['genre'] = df['genre'].str.replace('포크', 'Folk')
df['genre'] = df['genre'].str.replace('재즈', 'Jazz')
df['genre'] = df['genre'].str.replace('성인가요', 'Trot')
df['genre'] = df['genre'].str.replace('\(.*\)', '', regex = True)
df
# Out:
#                           year          type  \
# artists
# 기리보이 (홍시영)                2010    Solo, Male
# 김필                        2010    Solo, Male
# 김동률           1990, 2000, 2010    Solo, Male
# 김하온 (HAON)                2010    Solo, Male
# 김소유 (김소희)                 2010  Solo, Female
# ...                        ...           ...
# 휘인 (Whee In)              2010  Solo, Female
# 홍자 (박지민)                  2010  Solo, Female
# 헤이즈 (Heize)               2010  Solo, Female
# 한요한                       2010    Solo, Male
# 황윤성                       2010    Solo, Male
#
#                                                           genre
# artists
# 기리보이 (홍시영)           Ballad, Dance, Rap/Hiphop, R&B/Soul, Indie
# 김필            Ballad, Dance, R&B/Soul, Indie, Rock/Metal, Fo...
# 김동률                                                      Ballad
# 김하온 (HAON)                                   Ballad, Rap/Hiphop
# 김소유 (김소희)                                                  Trot
# ...                                                         ...
# 휘인 (Whee In)                Ballad, Dance, R&B/Soul, Rock/Metal
# 홍자 (박지민)                                    Ballad, Dance, Trot
# 헤이즈 (Heize)          Ballad, Dance, Rap/Hiphop, R&B/Soul, Indie
# 한요한                                Ballad, Rap/Hiphop, R&B/Soul
# 황윤성                                                       Dance
#
# [70 rows x 3 columns]
